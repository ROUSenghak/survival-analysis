# %% [markdown]
# # Survival Robustness
#
# Rebuilds Kaplan-Meier summaries, Cox diagnostics, AFT comparisons, prediction calibration tables, and robustness outputs across reference and sensitivity event definitions.
#
# This notebook is a front-end for the reproducible script `scripts/run_survival_analysis.py`. The script remains the canonical execution unit; this notebook is for inspection, reruns, and discussion.

# %%
from pathlib import Path
import subprocess
import pandas as pd
from IPython.display import display

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
TABLES_DIR = PROJECT_ROOT / 'reports' / 'tables'
DATA_DIR = PROJECT_ROOT / 'data' / 'processed'
print(PROJECT_ROOT)

# %% [markdown]
# ## Run the analysis
#
# Set `RUN_SCRIPT = True` when you want to regenerate the outputs. Leave it as `False` for quick review of existing tables.

# %%
RUN_SCRIPT = False

if RUN_SCRIPT:
    result = subprocess.run(['python3', 'scripts/run_survival_analysis.py'], cwd=PROJECT_ROOT, text=True, capture_output=True, check=True)
    print(result.stdout)
    if result.stderr:
        print(result.stderr)

# %% [markdown]
# ## Key outputs

# %% [markdown]
# ### `survival_km_summary.csv`
#
# KM, RMST, event, censoring, and horizon-survival summaries.

# %%
path = TABLES_DIR / 'survival_km_summary.csv'
df = pd.read_csv(path)
print(df.shape)
display(df.head(20))

# %% [markdown]
# ### `survival_event_complexity.csv`
#
# Events, buyers, and approximate events per parameter by event definition.

# %%
path = TABLES_DIR / 'survival_event_complexity.csv'
df = pd.read_csv(path)
print(df.shape)
display(df.head(20))

# %% [markdown]
# ### `survival_cox_models.csv`
#
# Cluster-robust Cox model coefficients. Sparse-category warnings should be treated as diagnostic evidence.

# %%
path = TABLES_DIR / 'survival_cox_models.csv'
df = pd.read_csv(path)
print(df.shape)
display(df.head(20))

# %% [markdown]
# ### `survival_aft_models.csv`
#
# Parametric AFT model comparisons.

# %%
path = TABLES_DIR / 'survival_aft_models.csv'
df = pd.read_csv(path)
print(df.shape)
display(df.head(20))

# %% [markdown]
# ### `survival_predictions_12_24m.csv`
#
# Risk-group calibration against the constructed BOAMP proxy event.

# %%
path = TABLES_DIR / 'survival_predictions_12_24m.csv'
df = pd.read_csv(path)
print(df.shape)
display(df.head(20))

# %% [markdown]
# ### `survival_temporal_validation.csv`
#
# Attempted temporal validation split and deferral reason where stable validation was not available.

# %%
path = TABLES_DIR / 'survival_temporal_validation.csv'
df = pd.read_csv(path)
print(df.shape)
display(df.head(20))
