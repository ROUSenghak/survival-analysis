# %% [markdown]
# # Temporal-Window Sensitivity
#
# Reruns candidate generation, scoring, ranking, event construction, and survival summaries for several temporal windows.
#
# This notebook is a front-end for the reproducible script `scripts/eval_m6d_temporal_window_sensitivity.py`. The script remains the canonical execution unit; this notebook is for inspection, reruns, and discussion.

# %%
from pathlib import Path
import subprocess
import pandas as pd
from IPython.display import display

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
TABLES_DIR = PROJECT_ROOT / 'reports' / 'tables'
DATA_DIR = PROJECT_ROOT / 'data' / 'processed'
print(PROJECT_ROOT)

# %% [markdown]
# ## Run the analysis
#
# Set `RUN_SCRIPT = True` when you want to regenerate the outputs. Leave it as `False` for quick review of existing tables.

# %%
RUN_SCRIPT = False

if RUN_SCRIPT:
    result = subprocess.run(['python3', 'scripts/eval_m6d_temporal_window_sensitivity.py'], cwd=PROJECT_ROOT, text=True, capture_output=True, check=True)
    print(result.stdout)
    if result.stderr:
        print(result.stderr)

# %% [markdown]
# ## Key outputs

# %% [markdown]
# ### `m6d_temporal_window_sensitivity.csv`
#
# Main window-level sensitivity table.

# %%
path = TABLES_DIR / 'm6d_temporal_window_sensitivity.csv'
df = pd.read_csv(path)
print(df.shape)
display(df.head(20))

# %% [markdown]
# ### `m6d_temporal_window_by_year.csv`
#
# Event counts by source publication year for each window.

# %%
path = TABLES_DIR / 'm6d_temporal_window_by_year.csv'
df = pd.read_csv(path)
print(df.shape)
display(df.head(20))

# %% [markdown]
# ### `m6d_temporal_window_by_cpv_division.csv`
#
# Event counts by CPV division for each window.

# %%
path = TABLES_DIR / 'm6d_temporal_window_by_cpv_division.csv'
df = pd.read_csv(path)
print(df.shape)
display(df.head(20))
