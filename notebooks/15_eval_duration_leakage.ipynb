# %% [markdown]
# # Duration Leakage Audit
#
# Compares the reference duration-centered design with no-temporal-score reranking and a broad forward-window design that does not center blocking on declared or imputed duration.
#
# This notebook is a front-end for the reproducible script `scripts/eval_duration_leakage.py`. The script remains the canonical execution unit; this notebook is for inspection, reruns, and discussion.

# %%
from pathlib import Path
import subprocess
import pandas as pd
from IPython.display import display

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
TABLES_DIR = PROJECT_ROOT / 'reports' / 'tables'
DATA_DIR = PROJECT_ROOT / 'data' / 'processed'
print(PROJECT_ROOT)

# %% [markdown]
# ## Run the analysis
#
# Set `RUN_SCRIPT = True` when you want to regenerate the outputs. Leave it as `False` for quick review of existing tables.

# %%
RUN_SCRIPT = False

if RUN_SCRIPT:
    result = subprocess.run(['python3', 'scripts/eval_duration_leakage.py'], cwd=PROJECT_ROOT, text=True, capture_output=True, check=True)
    print(result.stdout)
    if result.stderr:
        print(result.stderr)

# %% [markdown]
# ## Key outputs

# %% [markdown]
# ### `duration_leakage_linkage_sensitivity.csv`
#
# Link overlap, event changes, reuse, and event timing under alternative duration designs.

# %%
path = TABLES_DIR / 'duration_leakage_linkage_sensitivity.csv'
df = pd.read_csv(path)
print(df.shape)
display(df.head(20))

# %% [markdown]
# ### `duration_leakage_cox_duration_effect.csv`
#
# Duration-only Cox models under each event definition, with clustered and unclustered inference.

# %%
path = TABLES_DIR / 'duration_leakage_cox_duration_effect.csv'
df = pd.read_csv(path)
print(df.shape)
display(df.head(20))
